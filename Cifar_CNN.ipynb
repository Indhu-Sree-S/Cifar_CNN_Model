# %% [markdown]
# **CNN Model for Cifar Dataset**
#
# ---

# %% [markdown]
# *Importing Libraries*

# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,Dropout,Flatten,MaxPooling2D

# %% [markdown]
# *Split Train and Test Data*

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.cifar10.load_data()
# Out:
# ...
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

# %%
x_train/=255
x_test/=255
print('x_train shape:',x_train.shape)
print('Number of images in x_train',x_train.shape[0])
print('Number of images in x_test',x_test.shape[0])
# Out:
# x_train shape: (50000, 32, 32, 3)
# Number of images in x_train 50000
# Number of images in x_test 10000

# %%
input_shape=(32,32,3)

# %% [markdown]
# *Constructing a Model*

# %% [markdown]
# Convolution Neural Network Layers: Input Layer, Feature Learning, Classification, Output Layer

# %% [markdown]
# * Feature Learning : Convolution + Relu , Pooling , Convolution + Relu , Pooling

# %% [markdown]
# * Classification Layers : Flatten , Fully connected , Softmax

# %% [markdown]
# * Compile

# %%
model=Sequential()
model.add(Conv2D(32 ,kernel_size =( 3, 3) ,input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128,activation=tf.nn.relu))
model.add(Dropout(0.2))
model.add(Dense(10,activation=tf.nn.softmax))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(x=x_train,y=y_train,epochs=12,validation_split=0.3)
# Out:
# Epoch 1/12
# 1094/1094 [==============================] - 38s 34ms/step - loss: 1.6113 - accuracy: 0.4266 - val_loss: 1.3948 - val_accuracy: 0.5120
# Epoch 2/12
# 1094/1094 [==============================] - 36s 32ms/step - loss: 1.2871 - accuracy: 0.5472 - val_loss: 1.3040 - val_accuracy: 0.5485
# Epoch 3/12
# 1094/1094 [==============================] - 36s 33ms/step - loss: 1.1379 - accuracy: 0.6012 - val_loss: 1.1821 - val_accuracy: 0.5904
# Epoch 4/12
# 1094/1094 [==============================] - 36s 33ms/step - loss: 1.0204 - accuracy: 0.6439 - val_loss: 1.2888 - val_accuracy: 0.5678
# Epoch 5/12
# 1094/1094 [==============================] - 37s 34ms/step - loss: 0.9216 - accuracy: 0.6771 - val_loss: 1.1523 - val_accuracy: 0.6040
# Epoch 6/12
# 1094/1094 [==============================] - 37s 34ms/step - loss: 0.8341 - accuracy: 0.7106 - val_loss: 1.1876 - val_accuracy: 0.6033
# Epoch 7/12
# ...

# %% [markdown]
# *Model Accuracy*

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
image_index = 20
print(y_train[image_index])
plt.imshow(x_train[image_index])
x_train.shape
# Out:
# [4]
# (50000, 32, 32, 3)

# %% [markdown]
# *Training Sample Visualisation*

# %%
from matplotlib import pyplot
from keras.datasets import cifar10

# %% [markdown]
# *load dataset*

# %%
(trainX,trainY),(testX,testY) = cifar10.load_data()

# %% [markdown]
# *summarize loaded data*

# %%
print('Train: X=',trainX.shape,'Y=',trainY.shape)
print('Test: X=',testX.shape,'Y=',testY.shape)
# Out:
# Train: X= (50000, 32, 32, 3) Y= (50000, 1)
# Test: X= (10000, 32, 32, 3) Y= (10000, 1)

# %%
import  PIL, google.colab  
from PIL import  ImageEnhance , ImageOps  
from tensorflow.keras.preprocessing.image import img_to_array

# %% [markdown]
# *Model Evaluation*

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 1.3699 - accuracy: 0.6021
# [1.3698879480361938, 0.6021000146865845]

# %% [markdown]
# *Visualizing the Testing Data*

# %%
for i in range(36):
  pyplot.subplot(6,6,i+1)
  pyplot.imshow(testX[i])

# %% [markdown]
# *User Input of Index*

# %%
image_index=int(input('Enter Index Value to find a Picture : '))
# Out:
# Enter Index Value to find a Picture : 6

# %% [markdown]
# *Predection for the given index*

# %%
import numpy as np 
labels = '''airplane automobile bird cat deer dog frog horseship truck'''.split()
plt.imshow(testX[image_index])
n = np.array(testX[image_index])
print(n.size)
p = n.reshape(1, 32, 32, 3)
pred = labels[model.predict(p).argmax()]

print("The predicted image is {}".format(pred))
# Out:
# 3072
# The predicted image is automobile

# %% [markdown]
# ***User Input***

# %% [markdown]
# *Upload an Image*

# %%
google.colab.files.upload()
# Out:
#      <input type="file" id="files-0253c637-7b93-49a4-a861-6f9e78625083" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0253c637-7b93-49a4-a861-6f9e78625083">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving airplane.jpg to airplane.jpg
# ...

# %%
pic = PIL.Image.open('airplane.jpg')
plt.imshow(pic)

# %% [markdown]
# *Prediction*

# %%
pic1=ImageOps.grayscale(pic)
plt.imshow(pic1,cmap='Accent')



p1=pic.resize((32,32))
p1 = np.array(p1)
p1 = p1.reshape((1,32,32,3))



pred = labels[model.predict(p1).argmax()]

print("The predicted image is {}".format(pred))
# Out:
# The predicted image is airplane
